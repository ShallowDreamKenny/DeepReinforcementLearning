# %%
import gym

from stable_baselines3 import PPO

env = gym.make("CartPole-v1")

model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_0000)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(100):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render()
    # VecEnv resets automatically
    # if done:
    #   obs = env.reset()

env.close()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.5     |
# |    ep_rew_mean     | 22.5     |
# | time/              |          |
# |    fps             | 624      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | 24.6        |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009708287 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00575     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.9         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 57.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36          |
# |    ep_rew_mean          | 36          |
# | time/                   |             |
# |    fps                  | 430         |
# |    iterations           | 3           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009433921 |
# |    clip_fraction        | 0.061       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.0633      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 33.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.9        |
# |    ep_rew_mean          | 46.9        |
# | time/                   |             |
# |    fps                  | 417         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008054236 |
# |    clip_fraction        | 0.0689      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.643      |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 53.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 61.6        |
# |    ep_rew_mean          | 61.6        |
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 5           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008185945 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 61.8        |
# -----------------------------------------
